# %%
import pandas as pd

books = pd.read_csv("books_cleaned.csv")

# %%
books["categories"].value_counts().reset_index(name="count")
# Out:
#                      categories  count
# 0                       Fiction   2111
# 1              Juvenile Fiction    390
# 2     Biography & Autobiography    311
# 3                       History    207
# 4            Literary Criticism    124
# ..                          ...    ...
# 474                  Aged women      1
# 475                 Imperialism      1
# 476  Human-animal relationships      1
# 477                       Amish      1
# 478               Human cloning      1
#
# [479 rows x 2 columns]

# %%
books["categories"].value_counts().reset_index().query("count > 50")
# Out:
#                    categories  count
# 0                     Fiction   2111
# 1            Juvenile Fiction    390
# 2   Biography & Autobiography    311
# 3                     History    207
# 4          Literary Criticism    124
# 5                    Religion    117
# 6                  Philosophy    117
# 7     Comics & Graphic Novels    116
# 8                       Drama     86
# 9         Juvenile Nonfiction     57
# 10                    Science     56
# 11                     Poetry     51

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}
# Map detailed categories to simpler categories
books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
books[~(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 2     9780006178736  0006178731             Rage of angels
# 8     9780006482079  0006482074        Warhost of Vastmark
# 30    9780006646006  000664600X         Ocean Star Express
# 46    9780007121014  0007121016         Taken at the Flood
# ...             ...         ...                        ...
# 5178  9781933648279  1933648279  Night Has a Thousand Eyes
# 5188  9784770028969  4770028962         Coin Locker Babies
# 5189  9788122200850  8122200850           Cry, the Peacock
# 5195  9788185300535  8185300534                  I Am that
# 5196  9789027712059  9027712050   The Berlin Phenomenology
#
#                                            authors        categories  \
# 0                               Marilynne Robinson           Fiction
# 2                                   Sidney Sheldon           Fiction
# ...

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("Device count:", torch.cuda.device_count())
print("Device name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# Device count: 1
# Device name: NVIDIA GeForce RTX 2050

# %%
# Import the pipeline function from Hugging Face Transformers
from transformers import pipeline
# categories you want to classify text into
fiction_categories = ["Fiction", "Nonfiction"]

# Create a zero-shot classification pipeline using the BART model
pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli",   # Pretrained model name
                device=0)    # Device: 'mps' for Mac GPU, 0 for NVIDIA, '-1' for CPU
# Out:
# Device set to use cuda:0

# %%
#extracts the description of the first book in the dataset that has its simple_categories marked as "Fiction".
#books.loc to select particular data, .reset_index to reset index of data as it can be non-continuous, 0 to get the first one data which pass condition
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
# Classify the sequence as either "Fiction" or "Nonfiction" using zero-shot classification
pipe(sequence, fiction_categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the wor
# ...

# %%
import numpy as np

#This finds the category label with the highest confidence score from the model's prediction.
#np.argmax() finds the index of the highest score in the list:fiction/nonfiction(0,1)
max_index = np.argmax(pipe(sequence, fiction_categories)["scores"])
#now take label array and return the index with max probability using the max index
max_label = pipe(sequence, fiction_categories)["labels"][max_index]
max_label
# Out:
# 'Fiction'

# %%
#jus a function for above task and giving categories column as argument
def generate_predictions(sequence, categories):
    predictions = pipe(sequence, categories)
    max_index = np.argmax(predictions["scores"])
    max_label = predictions["labels"][max_index]
    return max_label

# %%
#This loop evaluates the model's prediction on the first 300 "Fiction" book descriptions, storing the actual and predicted categories for later comparison
from tqdm import tqdm #tells how much data left to process real time

actual_cats = []
predicted_cats = []

for i in tqdm(range(300, 600)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Fiction"]
#means in reality all the categories that model is predicting on is fiction but we're checking how correctly it predicts
# Out:
# ...
# 100%|██████████| 300/300 [00:33<00:00,  8.83it/s]

# %%
for i in tqdm(range(300, 600)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_predictions(sequence, fiction_categories)]
    actual_cats += ["Nonfiction"]
# Out:
# 100%|██████████| 300/300 [00:37<00:00,  7.93it/s]

# %%
predictions_df = pd.DataFrame({"actual_categories": actual_cats, "predicted_categories": predicted_cats})

# %%
predictions_df
# Out:
#     actual_categories predicted_categories
# 0             Fiction              Fiction
# 1             Fiction              Fiction
# 2             Fiction              Fiction
# 3             Fiction           Nonfiction
# 4             Fiction              Fiction
# ..                ...                  ...
# 295           Fiction              Fiction
# 296           Fiction           Nonfiction
# 297           Fiction              Fiction
# 298           Fiction           Nonfiction
# 299           Fiction              Fiction
#
# [300 rows x 2 columns]

# %%
predictions_df["correct_prediction"] = (
    np.where(predictions_df["actual_categories"] == predictions_df["predicted_categories"], 1, 0)
)
#created new column which has 0,1 value based on the condition

# %%
predictions_df["correct_prediction"].sum() / len(predictions_df)
#tells accuracy by sum of all 1(right pred.)/ total predictions
# Out:
# np.float64(0.7033333333333334)

# %%
isbns = []             # To store ISBNs of books with missing categories
predicted_cats = []    # To store predicted categories for those books

# Filter books where 'simple_categories' is missing (NaN), keep only ISBN and description
missing_cats = books.loc[books["simple_categories"].isna(), ["isbn13", "description"]].reset_index(drop=True)

# %%
for i in tqdm(range(0, len(missing_cats))):  # Loop through books with missing categories
    sequence = missing_cats["description"][i]             # Get book description
    predicted_cats += [generate_predictions(sequence, fiction_categories)]  # Predict category
    isbns += [missing_cats["isbn13"][i]]                  # Store corresponding ISBN
# Out:
# 100%|██████████| 1454/1454 [04:42<00:00,  5.15it/s]

# %%
# Create a new DataFrame with ISBNs and their predicted categories
missing_predicted_df = pd.DataFrame({
    "isbn13": isbns,
    "predicted_categories": predicted_cats
})

# %%
missing_predicted_df
# Out:
#              isbn13 predicted_categories
# 0     9780002261982              Fiction
# 1     9780006280897           Nonfiction
# 2     9780006280934           Nonfiction
# 3     9780006380832           Nonfiction
# 4     9780006470229              Fiction
# ...             ...                  ...
# 1449  9788125026600           Nonfiction
# 1450  9788171565641              Fiction
# 1451  9788172235222              Fiction
# 1452  9788173031014           Nonfiction
# 1453  9788179921623              Fiction
#
# [1454 rows x 2 columns]

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
# Merge predictions back into the main books DataFrame on isbn13
books = pd.merge(books, missing_predicted_df, on="isbn13", how="left")

# If 'simple_categories' is missing (NaN), fill it with predicted category
books["simple_categories"] = np.where(books["simple_categories"].isna(), books["predicted_categories"], books["simple_categories"])

# Drop the now-unneeded 'predicted_categories' column
books = books.drop(columns=["predicted_categories"])

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
books.to_csv("books_with_categories.csv", index=False)
